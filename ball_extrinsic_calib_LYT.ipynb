# %% [markdown]
# # Multiview ball extrinsic calibration
# Pre-request, you have run step1 intrinsic calibration. The `intrinsics_calib_carl.json` is previous outcome.

# %%
# import the necessary packages
import sys
sys.path.append('/home/gxj/Desktop/gxj/multiview_ball_calib/2A_ball_extrinsic_calib')
import pickle
import numpy as np
import json

intrinsics_json = '/home/gxj/Desktop/gxj/calibration_playground/intrinsic_calib_frames/intrinsics_calib.json'
#intrinsics_json = '/home/gxj/Desktop/gxj/calibration_playground/calibration_20231201/intrinsic_calib_frames/intrinsics_calib.json'

# %% [markdown]
# ## The input ball location data format
# The ball position in all view is stored in a `keypoints` variable, which is (NVIEW, NSAMPLE, NKEYPOINT=1, XYP=3).
#
# And the `P` in `XYP` is **0<=P<=1**, means the reliable of this detection. If you failed to detect a ball sometimes in a view, just set the `XY=np.nan`, and `P=0` for **IVIEW**. The `P` will be cutoff around `0.7` to auto delete reliable ball detections.

# %%
matfile = '/home/gxj/Desktop/gxj/calibration_playground/ball_label/ball.matpkl'
matdata = pickle.load(open(matfile, 'rb'))
assert 'keypoints' in matdata.keys()

print(matdata['keypoints'].shape) #(NVIEW, NSAMPLE, NKEYPOINT=1, xyp=3)
print(matdata['info'])            # The grid video. If you video is not grid. Just keep 'nview', 'fps'
print(matdata['views_xywh'])      # (NVIEW, 4) x,y,w,h. If you video is not grid in mycase, you just set x=0,y=0
# Out:
# (4, 100, 1, 3)
# {'nview': 4, 'fps': 30}
# [[   0    0 2448 2048]
#  [   0    0 2448 2048]
#  [   0    0 2448 2048]
#  [   0    0 2448 2048]]

# %% [markdown]
# ## Create a multiview tree
# Here is to set the `connectivity` between cameras. Give the hint which pairs of cameras are likely share/(connectivity) most views field of ball. In general case, all cameras share most common view field. You can use default config.
#
# For example, `0` share with `2`, `0` not with `1`, `1` share with `2`. You can set `"minimal_tree":{[0, 2], [1, 2]}` to global connection.
#
# Note that this `connectivity` define only works when calibration, and won't affect next step 2D<->3D transfrom.

# %%
nview=len(matdata['views_xywh'])
minimal_tree = [[i,i+1] for i in range(nview-1)]
setup_dict = {"views": list(range(nview)),
              "minimal_tree": minimal_tree}
setup_json = 'setup.json'
json.dump(setup_dict, open(setup_json, 'w'), indent=4)
print(setup_dict)
# Out:
# {'views': [0, 1, 2, 3], 'minimal_tree': [[0, 1], [1, 2], [2, 3]]}

# %% [markdown]
# ## Downsample the ball sample to <=1000
# It will do
# - Downsample ball sample to 1000
# - Pack all nessary informtion into one file

# %%
from matpkl2ballpkl import convert as convert_matpkl2ballpkl
# matfile = '/home/gxj/Desktop/gxj/calibration_playground/ball_label/ball.matpkl'
# intrinsics_json = '/home/gxj/Desktop/gxj/calibration_playground/intrinsic_calib_frames/intrinsics_calib.json'
setup_json = 'setup.json'
convert_matpkl2ballpkl(matfile, intrinsics_json, setup_json)
# Out:
# (4, 100, 2)
# ind_3notnan: [ True  True  True  True]
# Video file /home/gxj/Desktop/gxj/calibration_playground/ball_label/ball.mp4 does not exist
# python -m lilab.multiview_scripts_dev.s3_ballpkl2calibpkl /home/gxj/Desktop/gxj/calibration_playground/ball_label/ball.ballpkl
# '/home/gxj/Desktop/gxj/calibration_playground/ball_label/ball.ballpkl'

# %% [markdown]
# ## Content of `ballpkl`
# - **setup**: copy from `setup.json`
# - **intrinsics**: copy from `intrinsic_calib.json`
# - **landmarks_move_xy**: downsample ball xy position, (NVIEW, 1000, XY)
# - **background_img**: (NVIEW, )x(H,W,3) numpy array for background image each view, default not set
# - *landmarks_global_xy*, *landmarks_global_cm*, *global_iframe*: obsoleted

# %%
ballpklfile = matfile.replace('.matpkl', '.ballpkl')
ballpkl = pickle.load(open(ballpklfile, 'rb'))
print(ballpkl.keys())
print(ballpkl['landmarks_move_xy'].shape)
print(ballpkl['intrinsics'])
# Out:
# dict_keys(['landmarks_global_xy', 'landmarks_move_xy', 'global_iframe', 'landmarks_global_cm', 'background_img', 'setup', 'intrinsics'])
# (4, 100, 2)
# {'0': {'date': '2023-12-20 13:36:00', 'description': 'by opencv', 'K': [[1882, 0, 1231], [0, 1878, 1088], [0, 0, 1]], 'dist': [-0.182, 0.114, 0.0, 0.0, 0.0], 'image_shape': [2048, 2448]}, '1': {'date': '2023-12-20 13:36:00', 'description': 'by opencv', 'K': [[1946, 0, 1207], [0, 1944, 1067], [0, 0, 1]], 'dist': [-0.11, 0.372, 0.0, 0.0, 0.0], 'image_shape': [2048, 2448]}, '2': {'date': '2023-12-20 13:36:00', 'description': 'by opencv', 'K': [[1874, 0, 1207], [0, 1862, 1137], [0, 0, 1]], 'dist': [-0.18, 0.231, 0.0, 0.0, 0.0], 'image_shape': [2048, 2448]}, '3': {'date': '2023-12-20 13:36:00', 'description': 'by opencv', 'K': [[1843, 0, 1121], [0, 1820, 1163], [0, 0, 1]], 'dist': [-0.233, 0.206, 0.0, 0.0, 0.0], 'image_shape': [2048, 2448]}}

# %%
ballpklfile = '/home/gxj/Desktop/gxj/calibration_playground/ball_label/ball_1221.ballpkl'
ballpkl = pickle.load(open(ballpklfile, 'rb'))
print(ballpkl.keys())
print(ballpkl['landmarks_move_xy'].shape)
print(ballpkl['intrinsics'])
# Out:
# dict_keys(['landmarks_global_xy', 'landmarks_move_xy', 'global_iframe', 'landmarks_global_cm', 'background_img', 'setup', 'intrinsics'])
# (4, 100, 2)
# {'0': {'date': '2023-12-20 13:36:00', 'description': 'by opencv', 'K': [[1882, 0, 1231], [0, 1878, 1088], [0, 0, 1]], 'dist': [-0.182, 0.114, 0.0, 0.0, 0.0], 'image_shape': [2048, 2448]}, '1': {'date': '2023-12-20 13:36:00', 'description': 'by opencv', 'K': [[1946, 0, 1207], [0, 1944, 1067], [0, 0, 1]], 'dist': [-0.11, 0.372, 0.0, 0.0, 0.0], 'image_shape': [2048, 2448]}, '2': {'date': '2023-12-20 13:36:00', 'description': 'by opencv', 'K': [[1874, 0, 1207], [0, 1862, 1137], [0, 0, 1]], 'dist': [-0.18, 0.231, 0.0, 0.0, 0.0], 'image_shape': [2048, 2448]}, '3': {'date': '2023-12-20 13:36:00', 'description': 'by opencv', 'K': [[1843, 0, 1121], [0, 1820, 1163], [0, 0, 1]], 'dist': [-0.233, 0.206, 0.0, 0.0, 0.0], 'image_shape': [2048, 2448]}}

# %% [markdown]
# ## !! The most critical setup
# ## Multiview extrinsic calibration.
# The main precessing is :
# 1. Pair each two pair cameras in the `setup.json/mini_tree`.
# 2. Concat all views. Get a rough relative pose.
# 3. Remove outlier samples. Use bundle ajustment to refine relative poses.
#
# ![image.png](attachment:image.png)
#
# The outcome is `*.calibpkl` file.

# %%
from ballpkl2calibpkl import main_calibrate
calibpklfile = main_calibrate(ballpklfile, skip_global=True, skip_camera_intrinsic=True)
# Out:
# 2023-12-21 17:41:26,169 [root] -------------------------------------------------
# 2023-12-21 17:41:26,170 [root] Computing robust relative pose for pair 0->1
# 2023-12-21 17:41:26,171 [root] Initial relative pose:
# 2023-12-21 17:41:26,176 [root] Computing relative pose of pair [0, 1]:
# 2023-12-21 17:41:26,176 [root] 	0 out of 100 points considered outliers.
# 2023-12-21 17:41:26,179 [root] 	Residual error: 138.67379291716188
# 2023-12-21 17:41:26,181 [root] 	Sampson distance: 11468.449755164826
# 2023-12-21 17:41:26,182 [root] Number of additional paths found: 2
# 2023-12-21 17:41:26,186 [root] 	Computing relative pose of pair [0, 2]:
# 2023-12-21 17:41:26,186 [root] 		0 out of 100 points considered outliers.
# 2023-12-21 17:41:26,189 [root] 		Residual error: 190.19146472600684
# 2023-12-21 17:41:26,191 [root] 		Sampson distance: 8907.50532170125
# 2023-12-21 17:41:26,194 [root] 	Computing relative pose of pair [2, 1]:
# 2023-12-21 17:41:26,195 [root] 		0 out of 100 points considered outliers.
# 2023-12-21 17:41:26,198 [root] 		Residual error: 140.34510512801026
# 2023-12-21 17:41:26,199 [root] 		Sampson distance: 11568.815288847361
# 2023-12-21 17:41:26,206 [root] 	Concatenating relative poses for pair: (2, 1)
# 2023-12-21 17:41:26,206 [root] 		 Relative scale to (0, 2) n_points=100: 1.293+-4.864
# 2023-12-21 17:41:26,207 [root] 		 1 new position: [ 0.22181699  0.05864512 -0.29391522]
# 2023-12-21 17:41:26,211 [root] 	Computing relative pose of pair [0, 3]:
# 2023-12-21 17:41:26,212 [root] 		0 out of 100 points considered outliers.
# 2023-12-21 17:41:26,215 [root] 		Residual error: 28.24364153693465
# 2023-12-21 17:41:26,216 [root] 		Sampson distance: 835.0192072989817
# 2023-12-21 17:41:26,219 [root] 	Computing relative pose of pair [3, 1]:
# 2023-12-21 17:41:26,220 [root] 		0 out of 100 points considered outliers.
# 2023-12-21 17:41:26,223 [root] 		Residual error: 120.1787341942825
# 2023-12-21 17:41:26,224 [root] 		Sampson distance: 3255.3783653869295
# 2023-12-21 17:41:26,230 [root] 	Concatenating relative poses for pair: (3, 1)
# 2023-12-21 17:41:26,231 [root] 		 Relative scale to (0, 3) n_points=100: 1.147+-1.886
# 2023-12-21 17:41:26,232 [root] 		 1 new position: [0.11836045 0.04250192 1.36695491]
# 2023-12-21 17:41:26,234 [root] Final relative pose:
# 2023-12-21 17:41:26,236 [root] 	Residual error: 288.1914117087016
# 2023-12-21 17:41:26,238 [root] 	Sampson distance: 40887.69582730686
# 2023-12-21 17:41:26,239 [root] -------------------------------------------------
# 2023-12-21 17:41:26,239 [root] Computing robust relative pose for pair 1->2
# 2023-12-21 17:41:26,241 [root] Initial relative pose:
# 2023-12-21 17:41:26,244 [root] Computing relative pose of pair [1, 2]:
# 2023-12-21 17:41:26,245 [root] 	0 out of 100 points considered outliers.
# 2023-12-21 17:41:26,248 [root] 	Residual error: 140.34510512801035
# 2023-12-21 17:41:26,250 [root] 	Sampson distance: 11568.815288847403
# 2023-12-21 17:41:26,251 [root] Number of additional paths found: 2
# 2023-12-21 17:41:26,254 [root] 	Computing relative pose of pair [1, 0]:
# 2023-12-21 17:41:26,255 [root] 		0 out of 100 points considered outliers.
# 2023-12-21 17:41:26,258 [root] 		Residual error: 138.67379291716236
# 2023-12-21 17:41:26,259 [root] 		Sampson distance: 11468.449755164893
# 2023-12-21 17:41:26,262 [root] 	Computing relative pose of pair [0, 2]:
# 2023-12-21 17:41:26,263 [root] 		0 out of 100 points considered outliers.
# 2023-12-21 17:41:26,266 [root] 		Residual error: 190.19146472600684
# 2023-12-21 17:41:26,267 [root] 		Sampson distance: 8907.50532170125
# 2023-12-21 17:41:26,273 [root] 	Concatenating relative poses for pair: (0, 2)
# 2023-12-21 17:41:26,274 [root] 		 Relative scale to (1, 0) n_points=100: 7.407+-68.371
# 2023-12-21 17:41:26,276 [root] 		 2 new position: [-1.00846383  1.09178861  6.3373812 ]
# 2023-12-21 17:41:26,279 [root] 	Computing relative pose of pair [1, 3]:
# 2023-12-21 17:41:26,280 [root] 		0 out of 100 points considered outliers.
# 2023-12-21 17:41:26,283 [root] 		Residual error: 120.17873419428211
# 2023-12-21 17:41:26,284 [root] 		Sampson distance: 3255.378365386918
# 2023-12-21 17:41:26,287 [root] 	Computing relative pose of pair [3, 2]:
# 2023-12-21 17:41:26,288 [root] 		0 out of 100 points considered outliers.
# 2023-12-21 17:41:26,291 [root] 		Residual error: 118.66195485397051
# 2023-12-21 17:41:26,292 [root] 		Sampson distance: 5982.035325047162
# 2023-12-21 17:41:26,298 [root] 	Concatenating relative poses for pair: (3, 2)
# 2023-12-21 17:41:26,298 [root] 		 Relative scale to (1, 3) n_points=100: 2.098+-48.201
# 2023-12-21 17:41:26,300 [root] 		 2 new position: [ 0.76690837  0.13865616 -0.91463522]
# 2023-12-21 17:41:26,303 [root] Final relative pose:
# 2023-12-21 17:41:26,306 [root] 	Residual error: 906.2308011356987
# 2023-12-21 17:41:26,307 [root] 	Sampson distance: 248520.1394618219
# 2023-12-21 17:41:26,308 [root] -------------------------------------------------
# 2023-12-21 17:41:26,309 [root] Computing robust relative pose for pair 2->3
# 2023-12-21 17:41:26,310 [root] Initial relative pose:
# 2023-12-21 17:41:26,314 [root] Computing relative pose of pair [2, 3]:
# 2023-12-21 17:41:26,315 [root] 	0 out of 100 points considered outliers.
# 2023-12-21 17:41:26,318 [root] 	Residual error: 118.66195485397198
# 2023-12-21 17:41:26,320 [root] 	Sampson distance: 5982.035325047278
# 2023-12-21 17:41:26,321 [root] Number of additional paths found: 2
# 2023-12-21 17:41:26,327 [root] 	Computing relative pose of pair [2, 0]:
# 2023-12-21 17:41:26,329 [root] 		0 out of 100 points considered outliers.
# 2023-12-21 17:41:26,332 [root] 		Residual error: 190.19146472600542
# 2023-12-21 17:41:26,334 [root] 		Sampson distance: 8907.505321701063
# 2023-12-21 17:41:26,339 [root] 	Computing relative pose of pair [0, 3]:
# 2023-12-21 17:41:26,340 [root] 		0 out of 100 points considered outliers.
# 2023-12-21 17:41:26,344 [root] 		Residual error: 28.24364153693465
# 2023-12-21 17:41:26,346 [root] 		Sampson distance: 835.0192072989817
# 2023-12-21 17:41:26,353 [root] 	Concatenating relative poses for pair: (0, 3)
# 2023-12-21 17:41:26,354 [root] 		 Relative scale to (2, 0) n_points=100: 0.813+-0.749
# 2023-12-21 17:41:26,355 [root] 		 3 new position: [-0.46340944  0.47000037  0.16602436]
# 2023-12-21 17:41:26,362 [root] 	Computing relative pose of pair [2, 1]:
# 2023-12-21 17:41:26,363 [root] 		0 out of 100 points considered outliers.
# 2023-12-21 17:41:26,366 [root] 		Residual error: 140.34510512801026
# 2023-12-21 17:41:26,368 [root] 		Sampson distance: 11568.815288847361
# 2023-12-21 17:41:26,373 [root] 	Computing relative pose of pair [1, 3]:
# 2023-12-21 17:41:26,374 [root] 		0 out of 100 points considered outliers.
# 2023-12-21 17:41:26,378 [root] 		Residual error: 120.17873419428211
# 2023-12-21 17:41:26,381 [root] 		Sampson distance: 3255.378365386918
# 2023-12-21 17:41:26,390 [root] 	Concatenating relative poses for pair: (1, 3)
# 2023-12-21 17:41:26,391 [root] 		 Relative scale to (2, 1) n_points=100: 0.608+-1.645
# 2023-12-21 17:41:26,392 [root] 		 3 new position: [-0.16199957 -0.1157454   0.4014364 ]
# 2023-12-21 17:41:26,396 [root] Final relative pose:
# 2023-12-21 17:41:26,398 [root] 	Residual error: 1288.7801786560449
# 2023-12-21 17:41:26,401 [root] 	Sampson distance: 425704.39976529847
# 2023-12-21 17:41:26,451 [root] Concatenating relative poses for pair: (1, 2)
# 2023-12-21 17:41:26,452 [root] 	 Relative scale to (0, 1) n_points=100: 0.156+-0.602
# 2023-12-21 17:41:26,453 [root] 	 2 new position: [-0.10942602 -0.04491071  0.0810995 ]
# 2023-12-21 17:41:26,456 [root] Concatenating relative poses for pair: (2, 3)
# 2023-12-21 17:41:26,457 [root] 	 Relative scale to (1, 2) n_points=100: 2.133+-25.889
# 2023-12-21 17:41:26,458 [root] 	 3 new position: [-0.19023128 -0.00319848  0.03014906]
# 2023-12-21 17:41:27,374 [root] --------------------
# 2023-12-21 17:41:27,375 [root] Views: [0, 1, 2, 3]
# 2023-12-21 17:41:27,376 [root] Use all the landmarks.
# 2023-12-21 17:41:27,378 [root] Preparing the input data...(this can take a while depending on the number of points to triangulate)
# Fixing camera instrincis!
# 100%|██████████████████████████████████████| 100/100 [00:00<00:00, 22741.98it/s]
# 2023-12-21 17:41:27,394 [root] The preparation of the input data took: 0.01s
# 2023-12-21 17:41:27,394 [root] Sizes:
# 2023-12-21 17:41:27,396 [root] 	 camera_params: (4, 15)
# 2023-12-21 17:41:27,397 [root] 	 points_3d: (100, 3)
# 2023-12-21 17:41:27,397 [root] 	 points_2d: (400, 2)
# 2023-12-21 17:41:27,662 [root] Early Outlier rejection:
# 2023-12-21 17:41:27,664 [root] 	 threshold outliers: 100
# 2023-12-21 17:41:27,665 [root] 	 Number of points considered outliers: 399
# 2023-12-21 17:41:27,666 [root] !!!!!!!!!!!!!!!!!!!!
# 2023-12-21 17:41:27,667 [root] More than half of the data points have been considered outliers! Something may have gone wrong.
# 2023-12-21 17:41:27,668 [root] !!!!!!!!!!!!!!!!!!!!
# 2023-12-21 17:41:27,840 [multiview_calib.bundle_adjustment_scipy_short]    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
# 2023-12-21 17:41:27,842 [multiview_calib.bundle_adjustment_scipy_short]        0              1         2.4963e+03                                    3.06e+08
# 2023-12-21 17:41:27,851 [multiview_calib.bundle_adjustment_scipy_short]        1              2         6.3358e-01      2.50e+03       1.34e-02       4.99e+06
# 2023-12-21 17:41:27,859 [multiview_calib.bundle_adjustment_scipy_short]        2              3         4.3705e-08      6.34e-01       2.21e-04       1.35e+03
# 2023-12-21 17:41:27,868 [multiview_calib.bundle_adjustment_scipy_short]        3              4         1.2672e-22      4.37e-08       5.72e-08       7.68e-05
# 2023-12-21 17:41:27,869 [multiview_calib.bundle_adjustment_scipy_short] `xtol` termination condition is satisfied.
# 2023-12-21 17:41:27,870 [multiview_calib.bundle_adjustment_scipy_short] Function evaluations 4, initial cost 2.4963e+03, final cost 1.2672e-22, first-order optimality 7.68e-05.
# 2023-12-21 17:41:27,871 [root] Optimization took 0 seconds
# 2023-12-21 17:41:27,872 [root] Average absolute residual: 0.00 over 1.0 points.
# 2023-12-21 17:41:28,084 [root] Outlier rejection:
# 2023-12-21 17:41:28,085 [root] 	 threshold outliers: 20
# 2023-12-21 17:41:28,086 [root] 	 Number of points considered outliers: 0
# 2023-12-21 17:41:28,087 [root] 	 Exit.
# 2023-12-21 17:41:28,088 [root] Reprojection errors (mean+-std pixels):
# 2023-12-21 17:41:28,090 [root] 	 0 n_points=1: 0.000+-0.000
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 2
#       1 from ballpkl2calibpkl import main_calibrate
# ----> 2 calibpklfile = main_calibrate(ballpklfile, skip_global=True, skip_camera_intrinsic=True)
#
# File ~/Desktop/gxj/multiview_ball_calib/2A_ball_extrinsic_calib/ballpkl2calibpkl.py:516, in main_calibrate(ballfile, skip_global, skip_camera_intrinsic)
#     514     intrinsics_bounds = np.zeros(18) + 0.0001  #4+6+n
#     515     config["bounds_cp"] = [ 0.3, 0.3, 0.3, 100, 100, 100, *intrinsics_bounds]
# --> 516 ba_poses, ba_points = a3_bundle_ajustment(setup, poses, landmarks_move_xy, background_img,
#     517                                         config = config, iter1=100, iter2=200)
#     519 if skip_global:
#     520     print('Skipping global BA')
#
# File ~/Desktop/gxj/multiview_ball_calib/2A_ball_extrinsic_calib/ballpkl2calibpkl.py:385, in a3_bundle_ajustment(setup, pose, landmarks, filenames_images, config, iter1, iter2)
#     382 points2d = points_2d[camera_indices==i]
#     384 if len(points3d)==0:
# --> 385     raise RuntimeError("All 3D points have been discarded/considered outliers.")
#     387 mean_error, std_error = reprojection_error(R, t, K, dist, points3d, points2d)
#     388 logging.info("\t {} n_points={}: {:0.3f}+-{:0.3f}".format(view, len(points3d), mean_error, std_error))
#
# RuntimeError: All 3D points have been discarded/considered outliers.

# %%
from ballpkl2calibpkl import main_calibrate
ballpklfile = '/home/gxj/Desktop/gxj/calibration_playground/ball_label/ball_1221.ballpkl'
calibpklfile = main_calibrate(ballpklfile, skip_global=True, skip_camera_intrinsic=True)
# Out:
# 2023-12-21 17:40:27,820 [root] -------------------------------------------------
# 2023-12-21 17:40:27,822 [root] Computing robust relative pose for pair 0->1
# 2023-12-21 17:40:27,823 [root] Initial relative pose:
# 2023-12-21 17:40:27,865 [root] Computing relative pose of pair [0, 1]:
# 2023-12-21 17:40:27,866 [root] 	0 out of 100 points considered outliers.
# 2023-12-21 17:40:27,870 [root] 	Residual error: 138.67379291716188
# 2023-12-21 17:40:27,872 [root] 	Sampson distance: 11468.449755164826
# 2023-12-21 17:40:27,873 [root] Number of additional paths found: 2
# 2023-12-21 17:40:27,878 [root] 	Computing relative pose of pair [0, 2]:
# 2023-12-21 17:40:27,879 [root] 		0 out of 100 points considered outliers.
# 2023-12-21 17:40:27,883 [root] 		Residual error: 190.19146472600684
# 2023-12-21 17:40:27,885 [root] 		Sampson distance: 8907.50532170125
# 2023-12-21 17:40:27,888 [root] 	Computing relative pose of pair [2, 1]:
# 2023-12-21 17:40:27,889 [root] 		0 out of 100 points considered outliers.
# 2023-12-21 17:40:27,892 [root] 		Residual error: 140.34510512801026
# 2023-12-21 17:40:27,893 [root] 		Sampson distance: 11568.815288847361
# 2023-12-21 17:40:27,901 [root] 	Concatenating relative poses for pair: (2, 1)
# 2023-12-21 17:40:27,902 [root] 		 Relative scale to (0, 2) n_points=100: 1.293+-4.864
# 2023-12-21 17:40:27,903 [root] 		 1 new position: [ 0.22181699  0.05864512 -0.29391522]
# 2023-12-21 17:40:27,907 [root] 	Computing relative pose of pair [0, 3]:
# 2023-12-21 17:40:27,908 [root] 		0 out of 100 points considered outliers.
# 2023-12-21 17:40:27,911 [root] 		Residual error: 28.24364153693465
# 2023-12-21 17:40:27,912 [root] 		Sampson distance: 835.0192072989817
# 2023-12-21 17:40:27,916 [root] 	Computing relative pose of pair [3, 1]:
# 2023-12-21 17:40:27,918 [root] 		0 out of 100 points considered outliers.
# 2023-12-21 17:40:27,921 [root] 		Residual error: 120.1787341942825
# 2023-12-21 17:40:27,923 [root] 		Sampson distance: 3255.3783653869295
# 2023-12-21 17:40:27,929 [root] 	Concatenating relative poses for pair: (3, 1)
# 2023-12-21 17:40:27,930 [root] 		 Relative scale to (0, 3) n_points=100: 1.147+-1.886
# 2023-12-21 17:40:27,931 [root] 		 1 new position: [0.11836045 0.04250192 1.36695491]
# 2023-12-21 17:40:27,933 [root] Final relative pose:
# 2023-12-21 17:40:27,935 [root] 	Residual error: 288.1914117087016
# 2023-12-21 17:40:27,937 [root] 	Sampson distance: 40887.69582730686
# 2023-12-21 17:40:27,937 [root] -------------------------------------------------
# 2023-12-21 17:40:27,938 [root] Computing robust relative pose for pair 1->2
# 2023-12-21 17:40:27,939 [root] Initial relative pose:
# 2023-12-21 17:40:27,943 [root] Computing relative pose of pair [1, 2]:
# 2023-12-21 17:40:27,943 [root] 	0 out of 100 points considered outliers.
# 2023-12-21 17:40:27,946 [root] 	Residual error: 140.34510512801035
# 2023-12-21 17:40:27,948 [root] 	Sampson distance: 11568.815288847403
# 2023-12-21 17:40:27,948 [root] Number of additional paths found: 2
# 2023-12-21 17:40:27,952 [root] 	Computing relative pose of pair [1, 0]:
# 2023-12-21 17:40:27,953 [root] 		0 out of 100 points considered outliers.
# 2023-12-21 17:40:27,956 [root] 		Residual error: 138.67379291716236
# 2023-12-21 17:40:27,957 [root] 		Sampson distance: 11468.449755164893
# 2023-12-21 17:40:27,961 [root] 	Computing relative pose of pair [0, 2]:
# 2023-12-21 17:40:27,964 [root] 		0 out of 100 points considered outliers.
# 2023-12-21 17:40:27,968 [root] 		Residual error: 190.19146472600684
# 2023-12-21 17:40:27,970 [root] 		Sampson distance: 8907.50532170125
# 2023-12-21 17:40:27,982 [root] 	Concatenating relative poses for pair: (0, 2)
# 2023-12-21 17:40:27,983 [root] 		 Relative scale to (1, 0) n_points=100: 7.407+-68.371
# 2023-12-21 17:40:27,985 [root] 		 2 new position: [-1.00846383  1.09178861  6.3373812 ]
# 2023-12-21 17:40:27,992 [root] 	Computing relative pose of pair [1, 3]:
# 2023-12-21 17:40:27,994 [root] 		0 out of 100 points considered outliers.
# 2023-12-21 17:40:27,997 [root] 		Residual error: 120.17873419428211
# 2023-12-21 17:40:27,999 [root] 		Sampson distance: 3255.378365386918
# 2023-12-21 17:40:28,004 [root] 	Computing relative pose of pair [3, 2]:
# 2023-12-21 17:40:28,005 [root] 		0 out of 100 points considered outliers.
# 2023-12-21 17:40:28,008 [root] 		Residual error: 118.66195485397051
# 2023-12-21 17:40:28,010 [root] 		Sampson distance: 5982.035325047162
# 2023-12-21 17:40:28,018 [root] 	Concatenating relative poses for pair: (3, 2)
# 2023-12-21 17:40:28,019 [root] 		 Relative scale to (1, 3) n_points=100: 2.098+-48.201
# 2023-12-21 17:40:28,020 [root] 		 2 new position: [ 0.76690837  0.13865616 -0.91463522]
# 2023-12-21 17:40:28,022 [root] Final relative pose:
# 2023-12-21 17:40:28,025 [root] 	Residual error: 906.2308011356987
# 2023-12-21 17:40:28,026 [root] 	Sampson distance: 248520.1394618219
# 2023-12-21 17:40:28,028 [root] -------------------------------------------------
# 2023-12-21 17:40:28,028 [root] Computing robust relative pose for pair 2->3
# 2023-12-21 17:40:28,029 [root] Initial relative pose:
# 2023-12-21 17:40:28,034 [root] Computing relative pose of pair [2, 3]:
# 2023-12-21 17:40:28,034 [root] 	0 out of 100 points considered outliers.
# 2023-12-21 17:40:28,037 [root] 	Residual error: 118.66195485397198
# 2023-12-21 17:40:28,039 [root] 	Sampson distance: 5982.035325047278
# 2023-12-21 17:40:28,040 [root] Number of additional paths found: 2
# 2023-12-21 17:40:28,044 [root] 	Computing relative pose of pair [2, 0]:
# 2023-12-21 17:40:28,045 [root] 		0 out of 100 points considered outliers.
# 2023-12-21 17:40:28,048 [root] 		Residual error: 190.19146472600542
# 2023-12-21 17:40:28,050 [root] 		Sampson distance: 8907.505321701063
# 2023-12-21 17:40:28,055 [root] 	Computing relative pose of pair [0, 3]:
# 2023-12-21 17:40:28,056 [root] 		0 out of 100 points considered outliers.
# 2023-12-21 17:40:28,059 [root] 		Residual error: 28.24364153693465
# 2023-12-21 17:40:28,061 [root] 		Sampson distance: 835.0192072989817
# 2023-12-21 17:40:28,067 [root] 	Concatenating relative poses for pair: (0, 3)
# 2023-12-21 17:40:28,068 [root] 		 Relative scale to (2, 0) n_points=100: 0.813+-0.749
# 2023-12-21 17:40:28,070 [root] 		 3 new position: [-0.46340944  0.47000037  0.16602436]
# 2023-12-21 17:40:28,074 [root] 	Computing relative pose of pair [2, 1]:
# 2023-12-21 17:40:28,075 [root] 		0 out of 100 points considered outliers.
# 2023-12-21 17:40:28,077 [root] 		Residual error: 140.34510512801026
# 2023-12-21 17:40:28,079 [root] 		Sampson distance: 11568.815288847361
# 2023-12-21 17:40:28,082 [root] 	Computing relative pose of pair [1, 3]:
# 2023-12-21 17:40:28,086 [root] 		0 out of 100 points considered outliers.
# 2023-12-21 17:40:28,089 [root] 		Residual error: 120.17873419428211
# 2023-12-21 17:40:28,090 [root] 		Sampson distance: 3255.378365386918
# 2023-12-21 17:40:28,096 [root] 	Concatenating relative poses for pair: (1, 3)
# 2023-12-21 17:40:28,097 [root] 		 Relative scale to (2, 1) n_points=100: 0.608+-1.645
# 2023-12-21 17:40:28,098 [root] 		 3 new position: [-0.16199957 -0.1157454   0.4014364 ]
# 2023-12-21 17:40:28,100 [root] Final relative pose:
# 2023-12-21 17:40:28,103 [root] 	Residual error: 1288.7801786560449
# 2023-12-21 17:40:28,104 [root] 	Sampson distance: 425704.39976529847
# 2023-12-21 17:40:28,199 [root] Concatenating relative poses for pair: (1, 2)
# 2023-12-21 17:40:28,200 [root] 	 Relative scale to (0, 1) n_points=100: 0.156+-0.602
# 2023-12-21 17:40:28,201 [root] 	 2 new position: [-0.10942602 -0.04491071  0.0810995 ]
# 2023-12-21 17:40:28,208 [root] Concatenating relative poses for pair: (2, 3)
# 2023-12-21 17:40:28,209 [root] 	 Relative scale to (1, 2) n_points=100: 2.133+-25.889
# 2023-12-21 17:40:28,210 [root] 	 3 new position: [-0.19023128 -0.00319848  0.03014906]
# 2023-12-21 17:40:29,182 [root] --------------------
# 2023-12-21 17:40:29,183 [root] Views: [0, 1, 2, 3]
# 2023-12-21 17:40:29,184 [root] Use all the landmarks.
# 2023-12-21 17:40:29,186 [root] Preparing the input data...(this can take a while depending on the number of points to triangulate)
# Fixing camera instrincis!
# 100%|██████████████████████████████████████| 100/100 [00:00<00:00, 31165.88it/s]
# 2023-12-21 17:40:29,202 [root] The preparation of the input data took: 0.02s
# 2023-12-21 17:40:29,203 [root] Sizes:
# 2023-12-21 17:40:29,203 [root] 	 camera_params: (4, 15)
# 2023-12-21 17:40:29,204 [root] 	 points_3d: (100, 3)
# 2023-12-21 17:40:29,204 [root] 	 points_2d: (400, 2)
# 2023-12-21 17:40:29,395 [root] Early Outlier rejection:
# 2023-12-21 17:40:29,396 [root] 	 threshold outliers: 100
# 2023-12-21 17:40:29,397 [root] 	 Number of points considered outliers: 399
# 2023-12-21 17:40:29,398 [root] !!!!!!!!!!!!!!!!!!!!
# 2023-12-21 17:40:29,399 [root] More than half of the data points have been considered outliers! Something may have gone wrong.
# 2023-12-21 17:40:29,399 [root] !!!!!!!!!!!!!!!!!!!!
# 2023-12-21 17:40:29,575 [multiview_calib.bundle_adjustment_scipy_short]    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
# 2023-12-21 17:40:29,576 [multiview_calib.bundle_adjustment_scipy_short]        0              1         2.4963e+03                                    3.06e+08
# 2023-12-21 17:40:29,585 [multiview_calib.bundle_adjustment_scipy_short]        1              2         6.3358e-01      2.50e+03       1.34e-02       4.99e+06
# 2023-12-21 17:40:29,596 [multiview_calib.bundle_adjustment_scipy_short]        2              3         4.3705e-08      6.34e-01       2.21e-04       1.35e+03
# 2023-12-21 17:40:29,617 [multiview_calib.bundle_adjustment_scipy_short]        3              4         1.2672e-22      4.37e-08       5.72e-08       7.68e-05
# 2023-12-21 17:40:29,618 [multiview_calib.bundle_adjustment_scipy_short] `xtol` termination condition is satisfied.
# 2023-12-21 17:40:29,618 [multiview_calib.bundle_adjustment_scipy_short] Function evaluations 4, initial cost 2.4963e+03, final cost 1.2672e-22, first-order optimality 7.68e-05.
# 2023-12-21 17:40:29,619 [root] Optimization took 0 seconds
# 2023-12-21 17:40:29,620 [root] Average absolute residual: 0.00 over 1.0 points.
# 2023-12-21 17:40:29,810 [root] Outlier rejection:
# 2023-12-21 17:40:29,813 [root] 	 threshold outliers: 20
# 2023-12-21 17:40:29,813 [root] 	 Number of points considered outliers: 0
# 2023-12-21 17:40:29,814 [root] 	 Exit.
# 2023-12-21 17:40:29,814 [root] Reprojection errors (mean+-std pixels):
# 2023-12-21 17:40:29,815 [root] 	 0 n_points=1: 0.000+-0.000
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 3
#       1 from ballpkl2calibpkl import main_calibrate
#       2 ballpklfile = '/home/gxj/Desktop/gxj/calibration_playground/ball_label/ball_1221.ballpkl'
# ----> 3 calibpklfile = main_calibrate(ballpklfile, skip_global=True, skip_camera_intrinsic=True)
#
# File ~/Desktop/gxj/multiview_ball_calib/2A_ball_extrinsic_calib/ballpkl2calibpkl.py:516, in main_calibrate(ballfile, skip_global, skip_camera_intrinsic)
#     514     intrinsics_bounds = np.zeros(18) + 0.0001  #4+6+n
#     515     config["bounds_cp"] = [ 0.3, 0.3, 0.3, 100, 100, 100, *intrinsics_bounds]
# --> 516 ba_poses, ba_points = a3_bundle_ajustment(setup, poses, landmarks_move_xy, background_img,
#     517                                         config = config, iter1=100, iter2=200)
#     519 if skip_global:
#     520     print('Skipping global BA')
#
# File ~/Desktop/gxj/multiview_ball_calib/2A_ball_extrinsic_calib/ballpkl2calibpkl.py:385, in a3_bundle_ajustment(setup, pose, landmarks, filenames_images, config, iter1, iter2)
#     382 points2d = points_2d[camera_indices==i]
#     384 if len(points3d)==0:
# --> 385     raise RuntimeError("All 3D points have been discarded/considered outliers.")
#     387 mean_error, std_error = reprojection_error(R, t, K, dist, points3d, points2d)
#     388 logging.info("\t {} n_points={}: {:0.3f}+-{:0.3f}".format(view, len(points3d), mean_error, std_error))
#
# RuntimeError: All 3D points have been discarded/considered outliers.

# %% [markdown]
# ## Content of the outcome `calibpkl` file
# - **ba_poses**: all intrinsic & extrinsic parameters. `K` (3, 3), `dist`: (K1_K2_T1_T2_K3,), `t` (3,), `R` (3, 3)

# %%
calibpkl = pickle.load(open(calibpklfile, 'rb'))
print(calibpkl.keys())

print('ba_poses', calibpkl['ba_poses'])
calibpkl['ba_poses'][0]

# %% [markdown]
# ## Next step **[3] world axes registration** and **[4] 2D-3D mutual transformation**.
# The **world axes registration** is optional. If you don't want to do it, just skip it.
